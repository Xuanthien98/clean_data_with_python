# %%
import pandas as pd
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)


#Get values from Gsheet
gsheets = gc.open_by_key('1hGNNJBCJltpjMQmRhzRcIxjeIN5KntVlxoTZ_cKcOF0')
data = gsheets.worksheet('Life Expectancy Data').get_all_values()

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                0     1           2                3                4   \
# 0         Country  Year      Status  Life expectancy  Adult Mortality
# 1     Afghanistan  2015  Developing               65              263
# 2     Afghanistan  2014  Developing             59.9              271
# 3     Afghanistan  2013  Developing             59.9              268
# 4     Afghanistan  2012  Developing             59.5              272
# ...           ...   ...         ...              ...              ...
# 2934     Zimbabwe  2004  Developing             44.3              723
# 2935     Zimbabwe  2003  Developing             44.5              715
# 2936     Zimbabwe  2002  Developing             44.8               73
# 2937     Zimbabwe  2001  Developing             45.3              686
# 2938     Zimbabwe  2000  Developing               46              665
#
#                  5        6                       7            8        9   \
# 0     infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles
# 1                62     0.01             71.27962362           65     1154
# 2                64     0.01             73.52358168           62      492
# 3                66     0.01             73.21924272           64      430
# 4                69     0.01              78.1842153           67     2787
# ...             ...      ...                     ...          ...      ...
# 2934             27     4.36                       0           68       31
# 2935             26     4.06                       0            7      998
# 2936             25     4.43                       0           73      304
# 2937             25     1.72                       0           76      529
# 2938             24     1.68                       0           79     1483
#
#       ...     12                 13          14        15           16  \
# 0     ...  Polio  Total expenditure  Diphtheria  HIV/AIDS          GDP
# 1     ...      6               8.16          65       0.1    584.25921
# 2     ...     58               8.18          62       0.1   612.696514
# 3     ...     62               8.13          64       0.1   631.744976
# 4     ...     67               8.52          67       0.1      669.959
# ...   ...    ...                ...         ...       ...          ...
# 2934  ...     67               7.13          65      33.6   454.366654
# 2935  ...      7               6.52          68      36.7  453.3511552
# 2936  ...     73               6.53          71      39.8     57.34834
# 2937  ...     76               6.16          75      42.1   548.587312
# 2938  ...     78                7.1          78      43.5  547.3588785
#
#               17                    18                  19  \
# 0     Population  thinness  1-19 years  thinness 5-9 years
# 1       33736494                  17.2                17.3
# 2         327582                  17.5                17.5
# 3       31731688                  17.7                17.7
# 4        3696958                  17.9                  18
# ...          ...                   ...                 ...
# 2934    12777511                   9.4                 9.4
# 2935    12633897                   9.8                 9.9
# 2936      125525                   1.2                 1.3
# 2937    12366165                   1.6                 1.7
# 2938    12222251                    11                11.2
#
#                                    20         21
# 0     Income composition of resources  Schooling
# 1                               0.479       10.1
# 2                               0.476         10
# 3                                0.47        9.9
# 4                               0.463        9.8
# ...                               ...        ...
# 2934                            0.407        9.2
# 2935                            0.418        9.5
# 2936                            0.427         10
# 2937                            0.427        9.8
# 2938                            0.434        9.8
#
# [2939 rows x 22 columns]

# %%
df.columns = df.iloc[0]
df = df[1:]

# %%
df
#.reset_index()

# %%
df.head()
# Out:
# 0      Country  Year      Status Life expectancy Adult Mortality  \
# 1  Afghanistan  2015  Developing              65             263
# 2  Afghanistan  2014  Developing            59.9             271
# 3  Afghanistan  2013  Developing            59.9             268
# 4  Afghanistan  2012  Developing            59.5             272
# 5  Afghanistan  2011  Developing            59.2             275
#
# 0 infant deaths Alcohol percentage expenditure Hepatitis B Measles  ... Polio  \
# 1            62    0.01            71.27962362          65    1154  ...     6
# 2            64    0.01            73.52358168          62     492  ...    58
# 3            66    0.01            73.21924272          64     430  ...    62
# 4            69    0.01             78.1842153          67    2787  ...    67
# 5            71    0.01            7.097108703          68    3013  ...    68
#
# 0 Total expenditure Diphtheria HIV/AIDS         GDP Population  \
# 1              8.16         65      0.1   584.25921   33736494
# 2              8.18         62      0.1  612.696514     327582
# 3              8.13         64      0.1  631.744976   31731688
# 4              8.52         67      0.1     669.959    3696958
# 5              7.87         68      0.1   63.537231    2978599
#
# 0 thinness  1-19 years thinness 5-9 years Income composition of resources  \
# 1                 17.2               17.3                           0.479
# 2                 17.5               17.5                           0.476
# 3                 17.7               17.7                            0.47
# 4                 17.9                 18                           0.463
# 5                 18.2               18.2                           0.454
#
# 0 Schooling
# 1      10.1
# 2        10
# 3       9.9
# 4       9.8
# 5       9.5
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 1 to 2938
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   object
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2938 non-null   float64
#  4   Adult Mortality                  2938 non-null   float64
#  5   infant deaths                    2938 non-null   object
#  6   Alcohol                          2938 non-null   float64
#  7   percentage expenditure           2938 non-null   object
#  8   Hepatitis B                      2938 non-null   float64
#  9   Measles                          2938 non-null   object
#  10  BMI                              2938 non-null   float64
#  11  under-five deaths                2938 non-null   object
#  12  Polio                            2938 non-null   float64
#  13  Total expenditure                2938 non-null   float64
#  14  Diphtheria                       2938 non-null   float64
#  15  HIV/AIDS                         2938 non-null   object
#  16  GDP                              2938 non-null   float64
#  17  Population                       2938 non-null   float64
#  18  thinness  1-19 years             2938 non-null   float64
#  19  thinness 5-9 years               2938 non-null   float64
#  20  Income composition of resources  2938 non-null   float64
#  21  Schooling                        2938 non-null   float64
# dtypes: float64(14), object(8)
# memory usage: 505.1+ KB

# %%
# Checking for Null Values
df.isnull().sum()

# %%
df[df['Hepatitis B'] == '']
# Out:
# Empty DataFrame
# Columns: [Country, Year, Status, Life expectancy, Adult Mortality, infant deaths, Alcohol, percentage expenditure, Hepatitis B, Measles, BMI, under-five deaths, Polio, Total expenditure, Diphtheria, HIV/AIDS, GDP, Population, thinness  1-19 years, thinness 5-9 years, Income composition of resources, Schooling]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# **Tiến hành thay đổi giá trị '' (rỗng) thành NaN/Null**
#
# **Syntax: df.loc[ df[“column_name”] == “some_value”, “column_name”] = “value” **

# %%
df.loc[df['Hepatitis B'] == '', 'Hepatitis B'] = np.nan

# %%
header_list = df.columns.to_list()

# %%
#Dùng vòng lặp for thôi nào!
for i in header_list:
  df.loc[df[i] == '', i] = np.nan

# %% [markdown]
# **XỬ LÝ LỖI NaN / NULL TRONG DATA SET BẰNG CÁCH DROP NaN ĐÃ HỌC Ở KHÓA 1**

# %%
df = pd.DataFrame({
    'A': [np.nan, 2, 3, 4],  
    'B': [np.nan, np.nan, 2, 3], 
    'C': [np.nan]*3 + [3]}) 

df
# Out:
#      A    B    C
# 0  NaN  NaN  NaN
# 1  2.0  NaN  NaN
# 2  3.0  2.0  NaN
# 3  4.0  3.0  3.0

# %%
df.dropna()
df.dropna(how='all')

# %% [markdown]
# **XỬ LÝ LỖI NaN / NULL TRONG DATA SET BẰNG XỬ DỤNG KỸ THUẬT SIMPLE IMPUTER**
#
# **ML | Handle Missing Data with Simple Imputer **
#
# https://www.geeksforgeeks.org/ml-handle-missing-data-with-simple-imputer/

# %% [markdown]
# **IMPUTE / IMPUTATION LÀ GÌ???**

# %%
import numpy as np
 
# Importing the SimpleImputer class
from sklearn.impute import SimpleImputer
 

imputer = SimpleImputer(missing_values = np.nan,
                        strategy ='mean')
 
data = pd.DataFrame([[12, np.nan, 34], [10, 32, np.nan],
        [np.nan, 11, 20]])
 

# Imputing the data    
data_imputed = imputer.fit_transform(data)

# %%
data_imputed
# Out:
# array([[12. , 21.5, 34. ],
#        [10. , 32. , 27. ],
#        [11. , 11. , 20. ]])

# %%
data = pd.DataFrame([[12, np.nan, 34], [10, 32, np.nan],
        [np.nan, 11, 20]])
data
# Out:
#       0     1     2
# 0  12.0   NaN  34.0
# 1  10.0  32.0   NaN
# 2   NaN  11.0  20.0

# %% [markdown]
# **TIẾP TỤC XỬ LÝ VỚI DATA SET LIFE EXPECTANCY (LE) BẰNG PHƯƠNG PHÁP SimpleImputer TỪ sklearn**

# %%
# Replacing the Null Values with mean values of the data
from sklearn.impute import SimpleImputer

imputer=SimpleImputer(missing_values=np.nan ,strategy='mean')

df['Life expectancy']=imputer.fit_transform(df[['Life expectancy']])
df['Adult Mortality']=imputer.fit_transform(df[['Adult Mortality']])
df['Alcohol']=imputer.fit_transform(df[['Alcohol']])
df['Hepatitis B']=imputer.fit_transform(df[['Hepatitis B']])
df['BMI']=imputer.fit_transform(df[['BMI']])
df['Polio']=imputer.fit_transform(df[['Polio']])
df['Total expenditure']=imputer.fit_transform(df[['Total expenditure']])
df['Diphtheria']=imputer.fit_transform(df[['Diphtheria']])
df['GDP']=imputer.fit_transform(df[['GDP']])
df['Population']=imputer.fit_transform(df[['Population']])
df['thinness  1-19 years']=imputer.fit_transform(df[['thinness  1-19 years']])
df['thinness 5-9 years']=imputer.fit_transform(df[['thinness 5-9 years']])
df['Income composition of resources']=imputer.fit_transform(df[['Income composition of resources']])
df['Schooling']=imputer.fit_transform(df[['Schooling']])

# %% [markdown]
# **NẾU TIẾN HÀNH IMPUTATION NHƯ TRÊN DÙNG VÒNG LẶP FOR THÌ VIẾT NTN?**

# %%
#Đáp án?...

# %%
# Checking for Null Values
df.isnull().sum()

# %%
df.describe()
# Out:
# 0      Life expectancy  Adult Mortality      Alcohol  Hepatitis B  \
# count      2938.000000      2938.000000  2938.000000  2938.000000
# mean         69.224932       164.796448     4.602861    80.940461
# std           9.507640       124.080302     3.916288    22.586855
# min          36.300000         1.000000     0.010000     1.000000
# 25%          63.200000        74.000000     1.092500    80.940461
# 50%          72.000000       144.000000     4.160000    87.000000
# 75%          75.600000       227.000000     7.390000    96.000000
# max          89.000000       723.000000    17.870000    99.000000
#
# 0              BMI        Polio  Total expenditure   Diphtheria  \
# count  2938.000000  2938.000000        2938.000000  2938.000000
# mean     38.321247    82.550188           5.938190    82.324084
# std      19.927677    23.352143           2.400274    23.640073
# min       1.000000     3.000000           0.370000     2.000000
# 25%      19.400000    78.000000           4.370000    78.000000
# 50%      43.000000    93.000000           5.938190    93.000000
# 75%      56.100000    97.000000           7.330000    97.000000
# max      87.300000    99.000000          17.600000    99.000000
#
# 0                GDP    Population  thinness  1-19 years  thinness 5-9 years  \
# count    2938.000000  2.938000e+03           2938.000000         2938.000000
# mean     7483.158469  1.275338e+07              4.839704            4.870317
# std     13136.800417  5.381546e+07              4.394535            4.482708
# min         1.681350  3.400000e+01              0.100000            0.100000
# 25%       580.486996  4.189172e+05              1.600000            1.600000
# 50%      3116.561755  3.675929e+06              3.400000            3.400000
# 75%      7483.158469  1.275338e+07              7.100000            7.200000
# max    119172.741800  1.293859e+09             27.700000           28.600000
#
# 0      Income composition of resources    Schooling
# count                      2938.000000  2938.000000
# mean                          0.627551    11.992793
# std                           0.204820     3.264381
# min                           0.000000     0.000000
# 25%                           0.504250    10.300000
# 50%                           0.662000    12.100000
# 75%                           0.772000    14.100000
# max                           0.948000    20.700000

# %%
df.corr()
# Out:
# 0                                Life expectancy  Adult Mortality   Alcohol  \
# 0
# Life expectancy                         1.000000        -0.696359  0.391598
# Adult Mortality                        -0.696359         1.000000 -0.190408
# Alcohol                                 0.391598        -0.190408  1.000000
# Hepatitis B                             0.203771        -0.138591  0.075447
# BMI                                     0.559255        -0.381449  0.318070
# Polio                                   0.461574        -0.272694  0.213744
# Total expenditure                       0.207981        -0.110875  0.294898
# Diphtheria                              0.475418        -0.273014  0.215242
# GDP                                     0.430493        -0.277053  0.318591
# Population                             -0.019638        -0.012501 -0.030765
# thinness  1-19 years                   -0.472162         0.299863 -0.416946
# thinness 5-9 years                     -0.466629         0.305366 -0.405881
# Income composition of resources         0.692483        -0.440062  0.416099
# Schooling                               0.715066        -0.435108  0.497546
#
# 0                                Hepatitis B       BMI     Polio  \
# 0
# Life expectancy                     0.203771  0.559255  0.461574
# Adult Mortality                    -0.138591 -0.381449 -0.272694
# Alcohol                             0.075447  0.318070  0.213744
# Hepatitis B                         1.000000  0.134929  0.408519
# BMI                                 0.134929  1.000000  0.282156
# Polio                               0.408519  0.282156  1.000000
# Total expenditure                   0.050084  0.231814  0.130129
# Diphtheria                          0.499958  0.281059  0.673553
# GDP                                 0.062318  0.276645  0.193980
# Population                         -0.109811 -0.063238 -0.034882
# thinness  1-19 years               -0.105144 -0.532025 -0.219938
# thinness 5-9 years                 -0.108334 -0.538911 -0.220710
# Income composition of resources     0.150992  0.479837  0.355398
# Schooling                           0.171755  0.508105  0.385832
#
# 0                                Total expenditure  Diphtheria       GDP  \
# 0
# Life expectancy                           0.207981    0.475418  0.430493
# Adult Mortality                          -0.110875   -0.273014 -0.277053
# Alcohol                                   0.294898    0.215242  0.318591
# Hepatitis B                               0.050084    0.499958  0.062318
# BMI                                       0.231814    0.281059  0.276645
# Polio                                     0.130129    0.673553  0.193980
# Total expenditure                         1.000000    0.145597  0.121467
# Diphtheria                                0.145597    1.000000  0.182795
# GDP                                       0.121467    0.182795  1.000000
# Population                               -0.066698   -0.025458 -0.025612
# thinness  1-19 years                     -0.268724   -0.227820 -0.267745
# thinness 5-9 years                       -0.275240   -0.221105 -0.272400
# Income composition of resources           0.149095    0.371729  0.440317
# Schooling                                 0.218310    0.389944  0.429489
#
# 0                                Population  thinness  1-19 years  \
# 0
# Life expectancy                   -0.019638             -0.472162
# Adult Mortality                   -0.012501              0.299863
# Alcohol                           -0.030765             -0.416946
# Hepatitis B                       -0.109811             -0.105144
# BMI                               -0.063238             -0.532025
# Polio                             -0.034882             -0.219938
# Total expenditure                 -0.066698             -0.268724
# Diphtheria                        -0.025458             -0.227820
# GDP                               -0.025612             -0.267745
# Population                         1.000000              0.236117
# thinness  1-19 years               0.236117              1.000000
# thinness 5-9 years                 0.233941              0.939102
# Income composition of resources   -0.007951             -0.406662
# Schooling                         -0.029465             -0.446140
#
# 0                                thinness 5-9 years  \
# 0
# Life expectancy                           -0.466629
# Adult Mortality                            0.305366
# Alcohol                                   -0.405881
# Hepatitis B                               -0.108334
# BMI                                       -0.538911
# Polio                                     -0.220710
# Total expenditure                         -0.275240
# Diphtheria                                -0.221105
# GDP                                       -0.272400
# Population                                 0.233941
# thinness  1-19 years                       0.939102
# thinness 5-9 years                         1.000000
# Income composition of resources           -0.395779
# Schooling                                 -0.435777
#
# 0                                Income composition of resources  Schooling
# 0
# Life expectancy                                         0.692483   0.715066
# Adult Mortality                                        -0.440062  -0.435108
# Alcohol                                                 0.416099   0.497546
# Hepatitis B                                             0.150992   0.171755
# BMI                                                     0.479837   0.508105
# Polio                                                   0.355398   0.385832
# Total expenditure                                       0.149095   0.218310
# Diphtheria                                              0.371729   0.389944
# GDP                                                     0.440317   0.429489
# Population                                             -0.007951  -0.029465
# thinness  1-19 years                                   -0.406662  -0.446140
# thinness 5-9 years                                     -0.395779  -0.435777
# Income composition of resources                         1.000000   0.796207
# Schooling                                               0.796207   1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(data = df, x = 'Life expectancy')

# %%
sns.histplot(data = df, x = 'Schooling')

# %%
sns.histplot(data = df, x = 'Alcohol')

# %%
sns.histplot(data = df, x = 'Adult Mortality')

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='Year', y='Life expectancy', data=df,hue='Status')

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(x='Adult Mortality', y='Life expectancy', data=df,hue='Status')

# %%
sns.scatterplot(x='Hepatitis B', y='Life expectancy', data=df,hue='Status')

# %%
sns.scatterplot(x='Schooling', y='Life expectancy', data=df,hue='Status')

# %%
sns.scatterplot(x='GDP', y='Life expectancy', data=df,hue='Status')

# %% [markdown]
# **Observation**
#
# Life Expectancy of developed is higher.
#
# Year - from 2000 to 2015, there no much change in Life Expectancy, its same all years
#
# Adult Mortality -
#
# 0-100 - LE is varying all over range
# above 100, LE is dropping down as adult mortality increases, i.e Negative corelation with LE
#
# infant deaths-
#
# very less in Developed countries.
# Developed countries even with some infant mortality have high LE
# in some ranges, increase in value shows drop in LE
#
# Alcohol-
#
# No significant impact on LE
# some areas high value shows high LE, which is less likely to happen
# developed countries are not impacted by high alcohol , LE still on higher side
# percentage expenditure-
# high PE shows some increase in LE, reasonably looks true relation
#
# Hepatitis B-
#
# LE is spread low to high over hepatits B, no Significant relation observable
#
# Measeles-
#
# No Significant relation observable
#
# BMI-
#
# Higher BMI shows better LE
#
# under-five deaths-
# same as Infant Deaths
#
# Polio-
#
# Higher Polio shows better LE
#
# Total expenditure
#
# No Significant relation observable
#
# Diphtheria-
#
# within range of 20 - 50 LE is low, after that no signinficant difference
#
# HIV/AIDS-
# Higher HIV shows lower LE, expected.
#
# GDP -
#
# Higher GDP shows higher LE, as expexted
#
# Population-
#
# higher Population shows Higher LE, Need to investigate more.
#
# thinness-
#
# increase in thinnes shows lower LE
#
# Income composition of resources-
#
# increaseing value shows increase in LE
#
# Schooling-
#
# increaseing vlaue shows increase in LE
# Overall Observaiton with respect to LE
#
# Feature with Highr relation-
# status, Adult Mortality, percentage expenditure,HIV,GDP,schooling, Income composition of resources
# moderatly realtion -
# BMI, infant Death, under-five death
# less or No relation -
# Polio,Total expenditure, Diptheria,Population, Measles

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap='Greens')

# %% [markdown]
# **Observation inter feature correlation**
#
# Measels & infant death are correlated(0.5), Means mose infants died due to measels
#
# BMI -> Alcohol(0.33), More alchol causes higher BMI.
#
# under five & infant deaths (1), both are similer, one can be dropped
#
# Polio-> HepatitisB (0.49)
#
# Diptheria-> HepatitisB (0.61)
#
# Diptheria-> Polio (0.67)
#
# HIV -> Adult Mortality (0.52), many adults died due to HIV
#
# GDP -> percentage Expenditure (0.9)
#
# population -> infant deaths(0.56)
#
# thinness -> infant deaths(0.47)
#
# Both thiness have 1 correlation, one can be dropped
# Income composition of resources-> schooling(0.8), ->GDP(0.46),->alochol(0.45), ->BMI(0.51), -> diptheria(0.4), thinness(-0.4)
#
# Schooling->AdultM(-0.45), ->Alcohol(0.55), ->BMI(0.55), ->Polio(0.42), ->Diptheria(0.43), ->GDP(0.45), ->thiness(-.45)
